# %%
import numpy as np
from openpyxl import load_workbook
import matplotlib.pyplot as plt
import random

xpos = np.array([57, 16, 14, 47, 90, 55, 35, 80, 45, 38, 78, 36, 53, 71, 87, 32, 65, 97, 7])
ypos = np.array([80, 42, 72, 49, 80, 35, 7, 59, 91, 19, 43, 74, 3, 94, 76, 55, 18, 49, 51, 99])

# These arrays will be the order of travel
# xpath = np.array([xpos])
# ypath = np.array([ypos])
# path = np.array([xpos,ypos])
# print(f"path: {path.shape}\n{path}")

# The end of the paths will be the same as the starting point
xpath = np.append(xpos, xpos[0])
ypath = np.append(ypos, ypos[0])

# Define iterator, second parameter is the step size
# The first and the last coordinates in the paths will never be chosen
iterator = np.arange(1,xpos.size-1,1)

def get_distance(x1,y1,x2,y2):
    """x1/y1 correspond to first coordinate
    and x2/y2 correspond to second coordinate"""
    return np.sqrt((x2-x1)**2 + (y2-y1)**2)

def total_energy(x,y,iter):
    """x is the array path of x coordinates
    y is the array path of y coordinates"""
    total_energy = get_distance(x[0],y[0],x[iter[0]],y[iter[0]])
    for i in range(1, iter.size):
        energy = get_distance(x[iter[i]],y[iter[i]],x[iter[i-1]],y[iter[i-1]])
        total_energy += energy     
    # Get energy from last point to starting point
    energy = get_distance(x[iter.size],y[iter.size],x[0],y[0])
    total_energy += energy
    return total_energy


def swap(iter):
    rand_int = random.randrange(0, iterator.size - 2)
    iter[rand_int], iter[rand_int-1] = iter[rand_int-1], iter[rand_int]
    return iter

energy_list = np.array([])
energy_list = np.append(energy_list, total_energy(xpath,ypath,iterator))

plt.ion()
fig = plt.figure()
for i in range(1000):
    iterator = swap(iterator)
    energy = total_energy(xpos,ypos,iterator)
    subplot = fig.add_subplot(1,1,1)
    subplot.plot(np.append(np.append(xpos[0],xpos[iterator]),xpos[0]), np.append(np.append(ypos[0],ypos[iterator]),ypos[0]))
    fig.canvas.draw()
    fig.canvas.flush_events()
    if energy < energy_list[-1]:
        energy_list = np.append(energy_list, energy)

plt.plot(energy_list)
plt.show()

# delta E = E_i - E_i-1 

# where E_i is current energy and 
# E_i-1  is previous energy

# if delta E < 0, accept the current path
# else, do nothing and keep the old path
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5464\2788074198.py in <module>
#      53     subplot = fig.add_subplot(1,1,1)
#      54     subplot.plot(np.append(np.append(xpos[0],xpos[iterator]),xpos[0]), np.append(np.append(ypos[0],ypos[iterator]),ypos[0]))
# ---> 55     fig.canvas.draw()
#      56     fig.canvas.flush_events()
#      57     if energy < energy_list[-1]:
#
# c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2844             self.patch.draw(renderer)
#    2845             mimage._draw_list_compositing_images(
# -> 2846                 renderer, self, artists, self.suppressComposite)
#    2847
#    2848             for sfig in self.subfigs:
#
# c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer)
#    3040             self.apply_aspect(pos)
#    3041         else:
# -> 3042             self.apply_aspect()
#    3043
#    3044         artists = self.get_children()
#
# c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\matplotlib\axes\_base.py in apply_aspect(self, position)
#    1874         """
#    1875         if position is None:
# -> 1876             position = self.get_position(original=True)
#    1877
#    1878         aspect = self.get_aspect()
#
# c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\matplotlib\axes\_base.py in get_position(self, original)
#    1019         """
#    1020         if original:
# -> 1021             return self._originalPosition.frozen()
#    1022         else:
#    1023             locator = self.get_axes_locator()
#
# c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\matplotlib\transforms.py in frozen(self)
#     797     def frozen(self):
#     798         # docstring inherited
# --> 799         frozen_bbox = super().frozen()
#     800         frozen_bbox._minpos = self.minpos.copy()
#     801         return frozen_bbox
#
# c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\matplotlib\transforms.py in frozen(self)
#     258
#     259     def frozen(self):
# --> 260         return Bbox(self.get_points().copy())
#     261     frozen.__doc__ = TransformNode.__doc__
#     262
#
# c:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\site-packages\matplotlib\transforms.py in __init__(self, points, **kwargs)
#     783         # default or has been mutated; we store the orig points to
#     784         # support the mutated methods
# --> 785         self._points_orig = self._points.copy()
#     786     if DEBUG:
#     787         ___init__ = __init__
#
# KeyboardInterrupt:
